# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import CheckpointCallback
# Out:
# 2024-07-15 09:38:03.946797: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Create the environment
env = gym.make("CarRacing-v2")

# Wrap it with Monitor to keep track of statistics
env = Monitor(env)

# Vectorize the environment
env = DummyVecEnv([lambda: env])

# Optionally, stack frames
env = VecFrameStack(env, n_stack=4)

# %%
# Define the model - PPO is a commonly used algorithm for this environment
model = PPO("CnnPolicy", env, verbose=1, tensorboard_log="./ppo_carracing_tensorboard/")

# Define a checkpoint callback to save the model periodically
checkpoint_callback = CheckpointCallback(save_freq=10000, save_path='./logs/',
                                         name_prefix='ppo_carracing_model')

# Train the model
model.learn(total_timesteps=1_000_000, callback=checkpoint_callback)

# Save the final model
model.save("videos/ppo_carracing_model")

# To load the model later:
# model = PPO.load("ppo_carracing_model")
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# Logging to ./ppo_carracing_tensorboard/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -48.7    |
# | time/              |          |
# |    fps             | 95       |
# |    iterations      | 1        |
# |    time_elapsed    | 21       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -52.8       |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 2           |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007427128 |
# |    clip_fraction        | 0.0629      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | -0.00651    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.215       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00419    |
# |    std                  | 0.993       |
# |    value_loss           | 0.74        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -53.5       |
# | time/                   |             |
# |    fps                  | 53          |
# |    iterations           | 3           |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.007775733 |
# |    clip_fraction        | 0.0874      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0.15        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.295       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00627    |
# |    std                  | 0.986       |
# |    value_loss           | 0.603       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -51.2       |
# | time/                   |             |
# |    fps                  | 51          |
# |    iterations           | 4           |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011902012 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.21       |
# |    explained_variance   | 0.386       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.175       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0142     |
# |    std                  | 0.984       |
# |    value_loss           | 0.46        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -46.2       |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 5           |
# |    time_elapsed         | 211         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011329649 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.19       |
# |    explained_variance   | 0.41        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.112       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0117     |
# |    std                  | 0.975       |
# |    value_loss           | 0.463       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -43.7       |
# | time/                   |             |
# |    fps                  | 46          |
# |    iterations           | 6           |
# |    time_elapsed         | 265         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.009251058 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 0.246       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.224       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 0.967       |
# |    value_loss           | 0.582       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -41.1       |
# | time/                   |             |
# |    fps                  | 45          |
# |    iterations           | 7           |
# |    time_elapsed         | 313         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.013938484 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.14       |
# |    explained_variance   | 0.317       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.208       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0157     |
# |    std                  | 0.959       |
# |    value_loss           | 0.532       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -37.8        |
# | time/                   |              |
# |    fps                  | 45           |
# |    iterations           | 8            |
# |    time_elapsed         | 363          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0119330585 |
# |    clip_fraction        | 0.145        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.1         |
# |    explained_variance   | 0.153        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.118        |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0126      |
# |    std                  | 0.943        |
# |    value_loss           | 0.433        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -34         |
# | time/                   |             |
# |    fps                  | 44          |
# |    iterations           | 9           |
# |    time_elapsed         | 412         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.017041683 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.06       |
# |    explained_variance   | 0.369       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0543      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0234     |
# |    std                  | 0.932       |
# |    value_loss           | 0.43        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -33.3       |
# | time/                   |             |
# |    fps                  | 44          |
# |    iterations           | 10          |
# |    time_elapsed         | 460         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.019936185 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.01       |
# |    explained_variance   | 0.382       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.119       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0243     |
# |    std                  | 0.915       |
# |    value_loss           | 0.598       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -30.6       |
# | time/                   |             |
# |    fps                  | 44          |
# |    iterations           | 11          |
# |    time_elapsed         | 505         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.017824542 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.98       |
# |    explained_variance   | 0.711       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.183       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0207     |
# |    std                  | 0.911       |
# |    value_loss           | 0.445       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -27.4      |
# | time/                   |            |
# |    fps                  | 44         |
# |    iterations           | 12         |
# |    time_elapsed         | 552        |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.01953476 |
# |    clip_fraction        | 0.208      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.96      |
# |    explained_variance   | 0.81       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0228     |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0229    |
# |    std                  | 0.898      |
# |    value_loss           | 0.381      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -28         |
# | time/                   |             |
# |    fps                  | 44          |
# |    iterations           | 13          |
# |    time_elapsed         | 600         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.019734967 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.91       |
# |    explained_variance   | 0.783       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0966      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0219     |
# |    std                  | 0.886       |
# |    value_loss           | 0.601       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -30.4       |
# | time/                   |             |
# |    fps                  | 44          |
# |    iterations           | 14          |
# |    time_elapsed         | 648         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.021702299 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.87       |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0296      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0177     |
# |    std                  | 0.874       |
# |    value_loss           | 0.135       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -32.2       |
# | time/                   |             |
# |    fps                  | 44          |
# |    iterations           | 15          |
# |    time_elapsed         | 695         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.016728204 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.82       |
# |    explained_variance   | 0.894       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000513    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0185     |
# |    std                  | 0.86        |
# |    value_loss           | 0.188       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -33.2       |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 16          |
# |    time_elapsed         | 745         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.017078822 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.79       |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00399     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0142     |
# |    std                  | 0.855       |
# |    value_loss           | 0.197       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -33.7      |
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 17         |
# |    time_elapsed         | 795        |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.01742955 |
# |    clip_fraction        | 0.202      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.76      |
# |    explained_variance   | 0.921      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0184    |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0204    |
# |    std                  | 0.842      |
# |    value_loss           | 0.184      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | -31.3     |
# | time/                   |           |
# |    fps                  | 43        |
# |    iterations           | 18        |
# |    time_elapsed         | 842       |
# |    total_timesteps      | 36864     |
# | train/                  |           |
# |    approx_kl            | 0.0232164 |
# |    clip_fraction        | 0.191     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.72     |
# |    explained_variance   | 0.959     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0093    |
# |    n_updates            | 170       |
# |    policy_gradient_loss | -0.0199   |
# |    std                  | 0.833     |
# |    value_loss           | 0.22      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -30.7       |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 19          |
# |    time_elapsed         | 886         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.028302558 |
# |    clip_fraction        | 0.264       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.69       |
# |    explained_variance   | 0.875       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0987      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0191     |
# |    std                  | 0.826       |
# |    value_loss           | 0.675       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -29.3       |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 20          |
# |    time_elapsed         | 932         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.030871734 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.65       |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0082      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.025      |
# |    std                  | 0.811       |
# |    value_loss           | 0.208       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -22         |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 21          |
# |    time_elapsed         | 978         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.025047686 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.62       |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00698     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0279     |
# |    std                  | 0.812       |
# |    value_loss           | 0.469       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -14.8       |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 22          |
# |    time_elapsed         | 1028        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.030919071 |
# |    clip_fraction        | 0.307       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.61       |
# |    explained_variance   | 0.555       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.151       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0217     |
# |    std                  | 0.806       |
# |    value_loss           | 1.33        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -9.7        |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 23          |
# |    time_elapsed         | 1079        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.030854866 |
# |    clip_fraction        | 0.27        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.58       |
# |    explained_variance   | 0.78        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.119       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0177     |
# |    std                  | 0.797       |
# |    value_loss           | 1.6         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 0.415       |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 24          |
# |    time_elapsed         | 1128        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.034377232 |
# |    clip_fraction        | 0.322       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.55       |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.251       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0249     |
# |    std                  | 0.792       |
# |    value_loss           | 1.09        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 5.36      |
# | time/                   |           |
# |    fps                  | 43        |
# |    iterations           | 25        |
# |    time_elapsed         | 1176      |
# |    total_timesteps      | 51200     |
# | train/                  |           |
# |    approx_kl            | 0.0276988 |
# |    clip_fraction        | 0.296     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.53     |
# |    explained_variance   | 0.486     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.404     |
# |    n_updates            | 240       |
# |    policy_gradient_loss | -0.0201   |
# |    std                  | 0.785     |
# |    value_loss           | 1.98      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 10.3        |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 26          |
# |    time_elapsed         | 1225        |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.034315206 |
# |    clip_fraction        | 0.309       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.5        |
# |    explained_variance   | 0.917       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.152       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0245     |
# |    std                  | 0.776       |
# |    value_loss           | 1.03        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 15.8        |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 27          |
# |    time_elapsed         | 1277        |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.043783315 |
# |    clip_fraction        | 0.357       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.48       |
# |    explained_variance   | 0.912       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.223       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0239     |
# |    std                  | 0.775       |
# |    value_loss           | 1.09        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 26.1       |
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 28         |
# |    time_elapsed         | 1324       |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.04882825 |
# |    clip_fraction        | 0.343      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.47      |
# |    explained_variance   | 0.927      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.152      |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0193    |
# |    std                  | 0.769      |
# |    value_loss           | 1.15       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 35.6        |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 29          |
# |    time_elapsed         | 1371        |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.037696406 |
# |    clip_fraction        | 0.343       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.44       |
# |    explained_variance   | 0.826       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.591       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00982    |
# |    std                  | 0.765       |
# |    value_loss           | 2.29        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 40.5        |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 30          |
# |    time_elapsed         | 1421        |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.046943016 |
# |    clip_fraction        | 0.369       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.43       |
# |    explained_variance   | 0.838       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.382       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00839    |
# |    std                  | 0.763       |
# |    value_loss           | 3.54        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 43.4       |
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 31         |
# |    time_elapsed         | 1470       |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.05980705 |
# |    clip_fraction        | 0.374      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.42      |
# |    explained_variance   | 0.923      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.144      |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.0195    |
# |    std                  | 0.758      |
# |    value_loss           | 1.73       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 48.9        |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 32          |
# |    time_elapsed         | 1519        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.048015717 |
# |    clip_fraction        | 0.392       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.41       |
# |    explained_variance   | 0.922       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.466       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00309    |
# |    std                  | 0.758       |
# |    value_loss           | 2.5         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 57.4        |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 33          |
# |    time_elapsed         | 1567        |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.036129907 |
# |    clip_fraction        | 0.356       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.39       |
# |    explained_variance   | 0.922       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.386       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0128     |
# |    std                  | 0.753       |
# |    value_loss           | 2.39        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 65.4       |
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 34         |
# |    time_elapsed         | 1615       |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.05607517 |
# |    clip_fraction        | 0.389      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.37      |
# |    explained_variance   | 0.88       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.03       |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.00899   |
# |    std                  | 0.749      |
# |    value_loss           | 5.8        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 71.1        |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 35          |
# |    time_elapsed         | 1664        |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.059712835 |
# |    clip_fraction        | 0.412       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.36       |
# |    explained_variance   | 0.393       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.545       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0024     |
# |    std                  | 0.747       |
# |    value_loss           | 3.23        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 76.3        |
# | time/                   |             |
# |    fps                  | 42          |
# |    iterations           | 36          |
# |    time_elapsed         | 1715        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.050975494 |
# |    clip_fraction        | 0.383       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.34       |
# |    explained_variance   | 0.476       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.49        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0055     |
# |    std                  | 0.738       |
# |    value_loss           | 2.48        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 84.5        |
# | time/                   |             |
# |    fps                  | 42          |
# |    iterations           | 37          |
# |    time_elapsed         | 1764        |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.053454112 |
# |    clip_fraction        | 0.371       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.3        |
# |    explained_variance   | 0.654       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.459       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00713    |
# |    std                  | 0.733       |
# |    value_loss           | 2.57        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 90.7       |
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 38         |
# |    time_elapsed         | 1813       |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.05854583 |
# |    clip_fraction        | 0.371      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.28      |
# |    explained_variance   | 0.702      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.3        |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0076    |
# |    std                  | 0.727      |
# |    value_loss           | 2.78       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 95.9       |
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 39         |
# |    time_elapsed         | 1864       |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.04416231 |
# |    clip_fraction        | 0.387      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.26      |
# |    explained_variance   | 0.705      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.191      |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.00978   |
# |    std                  | 0.728      |
# |    value_loss           | 2.31       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 992        |
# |    ep_rew_mean          | 98.2       |
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 40         |
# |    time_elapsed         | 1911       |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.08192158 |
# |    clip_fraction        | 0.42       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.25      |
# |    explained_variance   | 0.858      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.325      |
# |    n_updates            | 390        |
# |    policy_gradient_loss | 0.00125    |
# |    std                  | 0.722      |
# |    value_loss           | 3.42       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 992       |
# |    ep_rew_mean          | 102       |
# | time/                   |           |
# |    fps                  | 42        |
# |    iterations           | 41        |
# |    time_elapsed         | 1962      |
# |    total_timesteps      | 83968     |
# | train/                  |           |
# |    approx_kl            | 0.3060581 |
# |    clip_fraction        | 0.519     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.24     |
# |    explained_variance   | 0.672     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.43      |
# |    n_updates            | 400       |
# |    policy_gradient_loss | 0.00438   |
# |    std                  | 0.72      |
# |    value_loss           | 8.75      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 992        |
# |    ep_rew_mean          | 111        |
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 42         |
# |    time_elapsed         | 2011       |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.07093753 |
# |    clip_fraction        | 0.447      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.23      |
# |    explained_variance   | 0.917      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.755      |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.00834   |
# |    std                  | 0.715      |
# |    value_loss           | 5.41       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 992       |
# |    ep_rew_mean          | 115       |
# | time/                   |           |
# |    fps                  | 42        |
# |    iterations           | 43        |
# |    time_elapsed         | 2062      |
# |    total_timesteps      | 88064     |
# | train/                  |           |
# |    approx_kl            | 0.0626073 |
# |    clip_fraction        | 0.452     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.21     |
# |    explained_variance   | 0.89      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.346     |
# |    n_updates            | 420       |
# |    policy_gradient_loss | 0.00512   |
# |    std                  | 0.713     |
# |    value_loss           | 4.37      |
# ---------------------------------------
