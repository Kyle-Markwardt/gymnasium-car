# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import CheckpointCallback

# %%
# Create the environment
env = gym.make("CarRacing-v2")

# Wrap it with Monitor to keep track of statistics
env = Monitor(env)

# Vectorize the environment
env = DummyVecEnv([lambda: env])

# Optionally, stack frames
env = VecFrameStack(env, n_stack=4)

# %%
# Define the model - PPO is a commonly used algorithm for this environment
model = PPO("CnnPolicy", env, verbose=1, tensorboard_log="./ppo_carracing_tensorboard/")
model.learning_rate = 0.0002  # Reduce learning rate
model.batch_size = 32  # Adjust batch size
model.vf_coef = 0.3  # Adjusted value function coefficient


# Define a checkpoint callback to save the model periodically
checkpoint_callback = CheckpointCallback(save_freq=10000, save_path='./logs/',
                                         name_prefix='ppo_carracing_model_v4')

# Train the model
model.learn(total_timesteps=1_000_000, callback=checkpoint_callback)

# Save the final model
model.save("videos/ppo_carracing_model_v4")

# To load the model later:
# model = PPO.load("ppo_carracing_model")
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# Logging to ./ppo_carracing_tensorboard/PPO_10
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -54.3    |
# | time/              |          |
# |    fps             | 76       |
# |    iterations      | 1        |
# |    time_elapsed    | 26       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -57.6       |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 2           |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007887762 |
# |    clip_fraction        | 0.058       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | -0.0228     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.115       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00473    |
# |    std                  | 0.992       |
# |    value_loss           | 0.598       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -58.8       |
# | time/                   |             |
# |    fps                  | 50          |
# |    iterations           | 3           |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009897126 |
# |    clip_fraction        | 0.0757      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | 0.152       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0276      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00711    |
# |    std                  | 0.963       |
# |    value_loss           | 0.393       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -55.7       |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 4           |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013239993 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.13       |
# |    explained_variance   | 0.114       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.2e-05     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0127     |
# |    std                  | 0.957       |
# |    value_loss           | 0.286       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -54.1       |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 5           |
# |    time_elapsed         | 217         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.013287055 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.14       |
# |    explained_variance   | 0.031       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0249      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0148     |
# |    std                  | 0.966       |
# |    value_loss           | 0.453       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -52.2       |
# | time/                   |             |
# |    fps                  | 45          |
# |    iterations           | 6           |
# |    time_elapsed         | 267         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.014084283 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.12       |
# |    explained_variance   | 0.0436      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0613      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0169     |
# |    std                  | 0.947       |
# |    value_loss           | 0.403       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -52.2       |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 7           |
# |    time_elapsed         | 327         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.027646663 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.06       |
# |    explained_variance   | 0.122       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0441     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.028      |
# |    std                  | 0.931       |
# |    value_loss           | 0.271       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -51         |
# | time/                   |             |
# |    fps                  | 41          |
# |    iterations           | 8           |
# |    time_elapsed         | 390         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.017551254 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.03       |
# |    explained_variance   | 0.11        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0148      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0166     |
# |    std                  | 0.926       |
# |    value_loss           | 0.283       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -50.1       |
# | time/                   |             |
# |    fps                  | 41          |
# |    iterations           | 9           |
# |    time_elapsed         | 448         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.027259745 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.99       |
# |    explained_variance   | 0.299       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0619     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0269     |
# |    std                  | 0.906       |
# |    value_loss           | 0.246       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -51.5      |
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 10         |
# |    time_elapsed         | 512        |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.02551156 |
# |    clip_fraction        | 0.223      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.94      |
# |    explained_variance   | 0.231      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0409    |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0254    |
# |    std                  | 0.892      |
# |    value_loss           | 0.259      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -52        |
# | time/                   |            |
# |    fps                  | 38         |
# |    iterations           | 11         |
# |    time_elapsed         | 578        |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.02392811 |
# |    clip_fraction        | 0.208      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.91      |
# |    explained_variance   | 0.465      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0497    |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0245    |
# |    std                  | 0.893      |
# |    value_loss           | 0.13       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -50.9       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 12          |
# |    time_elapsed         | 639         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.023169043 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.89       |
# |    explained_variance   | 0.602       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0272     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0268     |
# |    std                  | 0.878       |
# |    value_loss           | 0.172       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -52.6      |
# | time/                   |            |
# |    fps                  | 38         |
# |    iterations           | 13         |
# |    time_elapsed         | 697        |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.03754334 |
# |    clip_fraction        | 0.289      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.84      |
# |    explained_variance   | 0.429      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0512     |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0316    |
# |    std                  | 0.867      |
# |    value_loss           | 0.18       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -50.4       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 14          |
# |    time_elapsed         | 757         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.032655094 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.79       |
# |    explained_variance   | 0.715       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0275     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0306     |
# |    std                  | 0.852       |
# |    value_loss           | 0.0861      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -51.5       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 15          |
# |    time_elapsed         | 818         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.042265415 |
# |    clip_fraction        | 0.313       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.74       |
# |    explained_variance   | 0.35        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0106     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0402     |
# |    std                  | 0.834       |
# |    value_loss           | 0.24        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -52.4       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 16          |
# |    time_elapsed         | 883         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.038599566 |
# |    clip_fraction        | 0.29        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.69       |
# |    explained_variance   | 0.498       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0475     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0376     |
# |    std                  | 0.824       |
# |    value_loss           | 0.101       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -53.4       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 17          |
# |    time_elapsed         | 935         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.042748056 |
# |    clip_fraction        | 0.314       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.66       |
# |    explained_variance   | 0.823       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0487      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0347     |
# |    std                  | 0.816       |
# |    value_loss           | 0.0581      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -53.9       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 18          |
# |    time_elapsed         | 984         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.064464666 |
# |    clip_fraction        | 0.377       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.62       |
# |    explained_variance   | 0.839       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0355     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0396     |
# |    std                  | 0.801       |
# |    value_loss           | 0.0873      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -54.4      |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 19         |
# |    time_elapsed         | 1039       |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.07210089 |
# |    clip_fraction        | 0.372      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.58      |
# |    explained_variance   | 0.896      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0272    |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0424    |
# |    std                  | 0.796      |
# |    value_loss           | 0.0827     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -54.9       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 20          |
# |    time_elapsed         | 1099        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.062406108 |
# |    clip_fraction        | 0.344       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.55       |
# |    explained_variance   | 0.9         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0541     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0341     |
# |    std                  | 0.787       |
# |    value_loss           | 0.0992      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -54.6       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 21          |
# |    time_elapsed         | 1158        |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.076138094 |
# |    clip_fraction        | 0.4         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.52       |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00923    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0483     |
# |    std                  | 0.778       |
# |    value_loss           | 0.0671      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -55        |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 22         |
# |    time_elapsed         | 1213       |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.08863514 |
# |    clip_fraction        | 0.414      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.48      |
# |    explained_variance   | 0.841      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.079     |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0481    |
# |    std                  | 0.77       |
# |    value_loss           | 0.125      |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1e+03    |
# |    ep_rew_mean          | -55.4    |
# | time/                   |          |
# |    fps                  | 37       |
# |    iterations           | 23       |
# |    time_elapsed         | 1270     |
# |    total_timesteps      | 47104    |
# | train/                  |          |
# |    approx_kl            | 0.056498 |
# |    clip_fraction        | 0.337    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -3.44    |
# |    explained_variance   | 0.946    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.0118   |
# |    n_updates            | 220      |
# |    policy_gradient_loss | -0.0387  |
# |    std                  | 0.76     |
# |    value_loss           | 0.0759   |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -54.7       |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 24          |
# |    time_elapsed         | 1329        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.048978202 |
# |    clip_fraction        | 0.364       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.41       |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0522     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0377     |
# |    std                  | 0.751       |
# |    value_loss           | 0.112       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -54.2       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 25          |
# |    time_elapsed         | 1378        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.097636014 |
# |    clip_fraction        | 0.41        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.36       |
# |    explained_variance   | 0.835       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.053      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0486     |
# |    std                  | 0.735       |
# |    value_loss           | 0.142       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -53.9      |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 26         |
# |    time_elapsed         | 1426       |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.09167975 |
# |    clip_fraction        | 0.408      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.28      |
# |    explained_variance   | 0.907      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0536    |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0549    |
# |    std                  | 0.715      |
# |    value_loss           | 0.125      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -52.7      |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 27         |
# |    time_elapsed         | 1474       |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.12745783 |
# |    clip_fraction        | 0.424      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.2       |
# |    explained_variance   | 0.904      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0704    |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0531    |
# |    std                  | 0.698      |
# |    value_loss           | 0.114      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -52.1       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 28          |
# |    time_elapsed         | 1522        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.120982565 |
# |    clip_fraction        | 0.485       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.14       |
# |    explained_variance   | 0.756       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0831     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.053      |
# |    std                  | 0.686       |
# |    value_loss           | 0.145       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -51.2       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 29          |
# |    time_elapsed         | 1570        |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.101272136 |
# |    clip_fraction        | 0.487       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.1        |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0513     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0475     |
# |    std                  | 0.678       |
# |    value_loss           | 0.101       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -50.3       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 30          |
# |    time_elapsed         | 1617        |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.095297515 |
# |    clip_fraction        | 0.454       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.04       |
# |    explained_variance   | 0.867       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.091      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0577     |
# |    std                  | 0.664       |
# |    value_loss           | 0.145       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -48.7      |
# | time/                   |            |
# |    fps                  | 38         |
# |    iterations           | 31         |
# |    time_elapsed         | 1670       |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.16921106 |
# |    clip_fraction        | 0.507      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.99      |
# |    explained_variance   | 0.852      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.101     |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.0599    |
# |    std                  | 0.652      |
# |    value_loss           | 0.106      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -47.7      |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 32         |
# |    time_elapsed         | 1731       |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.12406748 |
# |    clip_fraction        | 0.475      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.92      |
# |    explained_variance   | 0.771      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.116     |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.0622    |
# |    std                  | 0.638      |
# |    value_loss           | 0.161      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -46.6      |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 33         |
# |    time_elapsed         | 1789       |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.13237514 |
# |    clip_fraction        | 0.485      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.87      |
# |    explained_variance   | 0.805      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0994    |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0648    |
# |    std                  | 0.628      |
# |    value_loss           | 0.111      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -46.1      |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 34         |
# |    time_elapsed         | 1844       |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.16178498 |
# |    clip_fraction        | 0.566      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.79      |
# |    explained_variance   | 0.781      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0692    |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.0542    |
# |    std                  | 0.609      |
# |    value_loss           | 0.14       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -44.8      |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 35         |
# |    time_elapsed         | 1903       |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.17992364 |
# |    clip_fraction        | 0.555      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.72      |
# |    explained_variance   | 0.721      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.132     |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0718    |
# |    std                  | 0.594      |
# |    value_loss           | 0.179      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -43.8      |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 36         |
# |    time_elapsed         | 1958       |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.17414883 |
# |    clip_fraction        | 0.584      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.65      |
# |    explained_variance   | 0.642      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0826    |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.0632    |
# |    std                  | 0.584      |
# |    value_loss           | 0.26       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -42        |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 37         |
# |    time_elapsed         | 2015       |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.23935899 |
# |    clip_fraction        | 0.6        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.59      |
# |    explained_variance   | 0.792      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0739    |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.064     |
# |    std                  | 0.571      |
# |    value_loss           | 0.262      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -40.8      |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 38         |
# |    time_elapsed         | 2069       |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.17238133 |
# |    clip_fraction        | 0.569      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.54      |
# |    explained_variance   | 0.785      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.101     |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0581    |
# |    std                  | 0.564      |
# |    value_loss           | 0.351      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -39.4      |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 39         |
# |    time_elapsed         | 2125       |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.18879202 |
# |    clip_fraction        | 0.583      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.48      |
# |    explained_variance   | 0.885      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0705    |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.0742    |
# |    std                  | 0.555      |
# |    value_loss           | 0.424      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -38.7      |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 40         |
# |    time_elapsed         | 2180       |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.24701777 |
# |    clip_fraction        | 0.602      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.42      |
# |    explained_variance   | 0.823      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0635    |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0574    |
# |    std                  | 0.537      |
# |    value_loss           | 0.338      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -35.6      |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 41         |
# |    time_elapsed         | 2235       |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.18174139 |
# |    clip_fraction        | 0.557      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.33      |
# |    explained_variance   | 0.853      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0459    |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0544    |
# |    std                  | 0.527      |
# |    value_loss           | 0.533      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -31.7      |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 42         |
# |    time_elapsed         | 2288       |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.30902046 |
# |    clip_fraction        | 0.617      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.3       |
# |    explained_variance   | 0.888      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0302     |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.063     |
# |    std                  | 0.521      |
# |    value_loss           | 0.609      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | -30.4     |
# | time/                   |           |
# |    fps                  | 37        |
# |    iterations           | 43        |
# |    time_elapsed         | 2339      |
# |    total_timesteps      | 88064     |
# | train/                  |           |
# |    approx_kl            | 0.2558484 |
# |    clip_fraction        | 0.632     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.25     |
# |    explained_variance   | 0.839     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0744   |
# |    n_updates            | 420       |
# |    policy_gradient_loss | -0.0605   |
# |    std                  | 0.511     |
# |    value_loss           | 0.973     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -27.3      |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 44         |
# |    time_elapsed         | 2394       |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.29596186 |
# |    clip_fraction        | 0.625      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.2       |
# |    explained_variance   | 0.946      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.037     |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.0536    |
# |    std                  | 0.504      |
# |    value_loss           | 0.455      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -23.4      |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 45         |
# |    time_elapsed         | 2449       |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.26065406 |
# |    clip_fraction        | 0.607      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.14      |
# |    explained_variance   | 0.885      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0483    |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.055     |
# |    std                  | 0.49       |
# |    value_loss           | 1.36       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -20.4      |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 46         |
# |    time_elapsed         | 2501       |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.31821877 |
# |    clip_fraction        | 0.634      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.08      |
# |    explained_variance   | 0.871      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0317    |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.0568    |
# |    std                  | 0.485      |
# |    value_loss           | 1.83       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -18.7      |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 47         |
# |    time_elapsed         | 2555       |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.38285083 |
# |    clip_fraction        | 0.663      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.04      |
# |    explained_variance   | 0.897      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.024      |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0527    |
# |    std                  | 0.475      |
# |    value_loss           | 1.33       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -14.3      |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 48         |
# |    time_elapsed         | 2613       |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.37911618 |
# |    clip_fraction        | 0.664      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.98      |
# |    explained_variance   | 0.904      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0454    |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.0365    |
# |    std                  | 0.467      |
# |    value_loss           | 1.04       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | -9.98     |
# | time/                   |           |
# |    fps                  | 37        |
# |    iterations           | 49        |
# |    time_elapsed         | 2670      |
# |    total_timesteps      | 100352    |
# | train/                  |           |
# |    approx_kl            | 0.3399046 |
# |    clip_fraction        | 0.646     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.93     |
# |    explained_variance   | 0.449     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0202    |
# |    n_updates            | 480       |
# |    policy_gradient_loss | -0.054    |
# |    std                  | 0.458     |
# |    value_loss           | 1.2       |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -1.84      |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 50         |
# |    time_elapsed         | 2723       |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.35408223 |
# |    clip_fraction        | 0.673      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.86      |
# |    explained_variance   | 0.892      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0139     |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.0579    |
# |    std                  | 0.449      |
# |    value_loss           | 1.27       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 6.93       |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 51         |
# |    time_elapsed         | 2776       |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.44969517 |
# |    clip_fraction        | 0.651      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.8       |
# |    explained_variance   | 0.592      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0425    |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.041     |
# |    std                  | 0.438      |
# |    value_loss           | 1.21       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 11.8      |
# | time/                   |           |
# |    fps                  | 37        |
# |    iterations           | 52        |
# |    time_elapsed         | 2831      |
# |    total_timesteps      | 106496    |
# | train/                  |           |
# |    approx_kl            | 0.2309672 |
# |    clip_fraction        | 0.641     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.74     |
# |    explained_variance   | 0.721     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0228   |
# |    n_updates            | 510       |
# |    policy_gradient_loss | -0.04     |
# |    std                  | 0.433     |
# |    value_loss           | 1.75      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 15.9       |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 53         |
# |    time_elapsed         | 2888       |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.50505006 |
# |    clip_fraction        | 0.707      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.71      |
# |    explained_variance   | 0.917      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00902   |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.0322    |
# |    std                  | 0.428      |
# |    value_loss           | 1.42       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 22        |
# | time/                   |           |
# |    fps                  | 37        |
# |    iterations           | 54        |
# ...
# |    total_timesteps      | 468992   |
# | train/                  |          |
# |    approx_kl            | 8.433924 |
# |    clip_fraction        | 0.867    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 3.88     |
# |    explained_variance   | 0.942    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0447  |
# |    n_updates            | 2280     |
# |    policy_gradient_loss | 0.0208   |
# |    std                  | 0.0665   |
# |    value_loss           | 0.187    |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 977       |
# |    ep_rew_mean          | -41.2     |
# | time/                   |           |
# |    fps                  | 29        |
# |    iterations           | 230       |
# |    time_elapsed         | 16142     |
# |    total_timesteps      | 471040    |
# | train/                  |           |
# |    approx_kl            | 1.6778615 |
# |    clip_fraction        | 0.759     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 3.92      |
# |    explained_variance   | 0.954     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0549   |
# |    n_updates            | 2290      |
# |    policy_gradient_loss | -0.00576  |
# |    std                  | 0.0658    |
# |    value_loss           | 0.123     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 977       |
# |    ep_rew_mean          | -41.3     |
# | time/                   |           |
# |    fps                  | 29        |
# |    iterations           | 231       |
# |    time_elapsed         | 16200     |
# |    total_timesteps      | 473088    |
# | train/                  |           |
# |    approx_kl            | 2.9935613 |
# |    clip_fraction        | 0.778     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 3.99      |
# |    explained_variance   | 0.963     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.024    |
# |    n_updates            | 2300      |
# |    policy_gradient_loss | -0.0265   |
# |    std                  | 0.0641    |
# |    value_loss           | 0.105     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 992       |
# |    ep_rew_mean          | -42.9     |
# | time/                   |           |
# |    fps                  | 29        |
# |    iterations           | 232       |
# |    time_elapsed         | 16262     |
# |    total_timesteps      | 475136    |
# | train/                  |           |
# |    approx_kl            | 1.0821726 |
# |    clip_fraction        | 0.756     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 4.04      |
# |    explained_variance   | 0.969     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0215    |
# |    n_updates            | 2310      |
# |    policy_gradient_loss | 0.00735   |
# |    std                  | 0.0634    |
# |    value_loss           | 0.108     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | -43.7     |
# | time/                   |           |
# |    fps                  | 29        |
# |    iterations           | 233       |
# |    time_elapsed         | 16325     |
# |    total_timesteps      | 477184    |
# | train/                  |           |
# |    approx_kl            | 2.1660628 |
# |    clip_fraction        | 0.749     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 4.07      |
# |    explained_variance   | 0.967     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0473   |
# |    n_updates            | 2320      |
# |    policy_gradient_loss | -0.006    |
# |    std                  | 0.0627    |
# |    value_loss           | 0.0944    |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1e+03    |
# |    ep_rew_mean          | -46.8    |
# | time/                   |          |
# |    fps                  | 29       |
# |    iterations           | 234      |
# |    time_elapsed         | 16387    |
# |    total_timesteps      | 479232   |
# | train/                  |          |
# |    approx_kl            | 2.732259 |
# |    clip_fraction        | 0.759    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 4.14     |
# |    explained_variance   | 0.981    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.089   |
# |    n_updates            | 2330     |
# |    policy_gradient_loss | -0.025   |
# |    std                  | 0.061    |
# |    value_loss           | 0.0776   |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | -48.1     |
# | time/                   |           |
# |    fps                  | 29        |
# |    iterations           | 235       |
# |    time_elapsed         | 16452     |
# |    total_timesteps      | 481280    |
# | train/                  |           |
# |    approx_kl            | 2.1918635 |
# |    clip_fraction        | 0.783     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 4.19      |
# |    explained_variance   | 0.981     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0153   |
# |    n_updates            | 2340      |
# |    policy_gradient_loss | 0.00162   |
# |    std                  | 0.0605    |
# |    value_loss           | 0.0734    |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1e+03    |
# |    ep_rew_mean          | -50.8    |
# | time/                   |          |
# |    fps                  | 29       |
# |    iterations           | 236      |
# |    time_elapsed         | 16509    |
# |    total_timesteps      | 483328   |
# | train/                  |          |
# |    approx_kl            | 8.350462 |
# |    clip_fraction        | 0.856    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 4.22     |
# |    explained_variance   | 0.904    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.0237   |
# |    n_updates            | 2350     |
# |    policy_gradient_loss | 0.0229   |
# |    std                  | 0.0596   |
# |    value_loss           | 0.271    |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | -52.5     |
# | time/                   |           |
# |    fps                  | 29        |
# |    iterations           | 237       |
# |    time_elapsed         | 16572     |
# |    total_timesteps      | 485376    |
# | train/                  |           |
# |    approx_kl            | 1.7929437 |
# |    clip_fraction        | 0.82      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 4.26      |
# |    explained_variance   | 0.969     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0135   |
# |    n_updates            | 2360      |
# |    policy_gradient_loss | 0.055     |
# |    std                  | 0.0591    |
# |    value_loss           | 0.0901    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | -53.9     |
# | time/                   |           |
# |    fps                  | 29        |
# |    iterations           | 238       |
# |    time_elapsed         | 16636     |
# |    total_timesteps      | 487424    |
# | train/                  |           |
# |    approx_kl            | 1.7101341 |
# |    clip_fraction        | 0.775     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 4.32      |
# |    explained_variance   | 0.967     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00492  |
# |    n_updates            | 2370      |
# |    policy_gradient_loss | 0.0016    |
# |    std                  | 0.0578    |
# |    value_loss           | 0.111     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | -57.9     |
# | time/                   |           |
# |    fps                  | 29        |
# |    iterations           | 239       |
# |    time_elapsed         | 16703     |
# |    total_timesteps      | 489472    |
# | train/                  |           |
# |    approx_kl            | 1.0606794 |
# |    clip_fraction        | 0.737     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 4.37      |
# |    explained_variance   | 0.981     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0391   |
# |    n_updates            | 2380      |
# |    policy_gradient_loss | 0.02      |
# |    std                  | 0.057     |
# |    value_loss           | 0.105     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | -59.7     |
# | time/                   |           |
# |    fps                  | 29        |
# |    iterations           | 240       |
# |    time_elapsed         | 16765     |
# |    total_timesteps      | 491520    |
# | train/                  |           |
# |    approx_kl            | 2.0446281 |
# |    clip_fraction        | 0.741     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 4.42      |
# |    explained_variance   | 0.982     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0109    |
# |    n_updates            | 2390      |
# |    policy_gradient_loss | -0.0203   |
# |    std                  | 0.0561    |
# |    value_loss           | 0.0766    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | -59.5     |
# | time/                   |           |
# |    fps                  | 29        |
# |    iterations           | 241       |
# |    time_elapsed         | 16821     |
# |    total_timesteps      | 493568    |
# | train/                  |           |
# |    approx_kl            | 3.9698782 |
# |    clip_fraction        | 0.816     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 4.47      |
# |    explained_variance   | 0.968     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0746   |
# |    n_updates            | 2400      |
# |    policy_gradient_loss | 0.00398   |
# |    std                  | 0.0552    |
# |    value_loss           | 0.106     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -60.3      |
# | time/                   |            |
# |    fps                  | 29         |
# |    iterations           | 242        |
# |    time_elapsed         | 16881      |
# |    total_timesteps      | 495616     |
# | train/                  |            |
# |    approx_kl            | 0.54410034 |
# |    clip_fraction        | 0.764      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 4.47       |
# |    explained_variance   | 0.992      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0666    |
# |    n_updates            | 2410       |
# |    policy_gradient_loss | 0.0366     |
# |    std                  | 0.056      |
# |    value_loss           | 0.0614     |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1e+03    |
# |    ep_rew_mean          | -60.5    |
# | time/                   |          |
# |    fps                  | 29       |
# |    iterations           | 243      |
# |    time_elapsed         | 16948    |
# |    total_timesteps      | 497664   |
# | train/                  |          |
# |    approx_kl            | 2.15938  |
# |    clip_fraction        | 0.805    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 4.48     |
# |    explained_variance   | 0.985    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0454  |
# |    n_updates            | 2420     |
# |    policy_gradient_loss | 0.00249  |
# |    std                  | 0.0547   |
# |    value_loss           | 0.0728   |
# --------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 13
#       9 checkpoint_callback = CheckpointCallback(save_freq=10000, save_path='./logs/',
#      10                                          name_prefix='ppo_carracing_model_v4')
#      12 # Train the model
# ---> 13 model.learn(total_timesteps=1_000_000, callback=checkpoint_callback)
#      15 # Save the final model
#      16 model.save("videos/ppo_carracing_model_v4")
#
# File ~/anaconda3/envs/rlcar_viz/lib/python3.9/site-packages/stable_baselines3/ppo/ppo.py:315, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     306 def learn(
#     307     self: SelfPPO,
#     308     total_timesteps: int,
#    (...)
#     313     progress_bar: bool = False,
#     314 ) -> SelfPPO:
# --> 315     return super().learn(
#     316         total_timesteps=total_timesteps,
#     317         callback=callback,
#     318         log_interval=log_interval,
#     319         tb_log_name=tb_log_name,
#     320         reset_num_timesteps=reset_num_timesteps,
#     321         progress_bar=progress_bar,
#     322     )
#
# File ~/anaconda3/envs/rlcar_viz/lib/python3.9/site-packages/stable_baselines3/common/on_policy_algorithm.py:313, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     310         assert self.ep_info_buffer is not None
#     311         self._dump_logs(iteration)
# --> 313     self.train()
#     315 callback.on_training_end()
#     317 return self
#
# File ~/anaconda3/envs/rlcar_viz/lib/python3.9/site-packages/stable_baselines3/ppo/ppo.py:279, in PPO.train(self)
#     277 # Optimization step
#     278 self.policy.optimizer.zero_grad()
# --> 279 loss.backward()
#     280 # Clip grad norm
#     281 th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
#
# File ~/anaconda3/envs/rlcar_viz/lib/python3.9/site-packages/torch/_tensor.py:522, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     512 if has_torch_function_unary(self):
#     513     return handle_torch_function(
#     514         Tensor.backward,
#     515         (self,),
#    (...)
#     520         inputs=inputs,
#     521     )
# --> 522 torch.autograd.backward(
#     523     self, gradient, retain_graph, create_graph, inputs=inputs
#     524 )
#
# File ~/anaconda3/envs/rlcar_viz/lib/python3.9/site-packages/torch/autograd/__init__.py:266, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     261     retain_graph = create_graph
#     263 # The reason we repeat the same comment below is that
#     264 # some Python versions print out the first line of a multi-line function
#     265 # calls in the traceback and some print out the last line
# --> 266 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     267     tensors,
#     268     grad_tensors_,
#     269     retain_graph,
#     270     create_graph,
#     271     inputs,
#     272     allow_unreachable=True,
#     273     accumulate_grad=True,
#     274 )
#
# KeyboardInterrupt:
